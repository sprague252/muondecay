# %%
import MuonJupyter as muonj
import numpy as np

# %%
c1 = muonj.controlpanel(['port', 'file'])
# Out:
# VBox(children=(RadioButtons(description='Select Port:', options=('/dev/ttyS4', '/dev/ttyS31', '/dev/ttyS30', '…

# %%
c1.file.value
# Out:
# 'muon.txt'

# %%
c1.append.value
# Out:
# False

# %%
c1.port.value
# Out:
# '/dev/ttyUSB0'

# %%
muonj.deltaports()
# Out:
# Serial ports scanned ...
# Connect new device. Then press any key ...
# ['/dev/ttyUSB0']

# %%
from subprocess import Popen, STDOUT

# %%
fh = open('temp', 'w+')
proc = Popen(['sleep', '30;', 'ls', '-l'], stderr=STDOUT, stdout=fh)

# %% [raw]
# proc.pid

# %%
proc.args
# Out:
# ['sleep', '30;', 'ls', '-l']

# %%
proc=''

# %%
fh
# Out:
# <_io.TextIOWrapper name='temp' mode='w+' encoding='UTF-8'>

# %%
fh.closed
# Out:
# False

# %%
fh.close()

# %%
proc30 = Popen(['sleep', '30'])

# %%
proc30.pid
# Out:
# 7339

# %%
proc30=''

# %%
proc.pid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 proc.pid
#
# AttributeError: 'str' object has no attribute 'pid'

# %%
proc=''

# %%
proc30=''

# %%
pid = Popen(['sleep', '30']).pid
pid
# Out:
# 7341

# %%
pid = ''

# %%
str(10)
# Out:
# '10'

# %%
muonj.detect_spawn(c1.port.value)
# Out:
# <Popen: returncode: None args: ['python', '-m', 'detect', '-n', '0', '-t', '...>

# %%
muonj.detect_monitor(mtime=120)
# Out:
# Monitor period 120 s ended.  Run again to continue monitoring.
# array([ 0.06,  0.04,  2.26,  0.04, 19.12,  0.06,  0.04,  0.06,  0.06,
#         0.04,  3.7 ,  0.04,  0.04,  0.06,  0.06,  0.06,  0.06])

# %%
print(__name__)
# Out:
# __main__

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
muonj.detect_monitor()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import MuonJupyter as muonj
import numpy as np

# %%
# %matplotlib inline

# %%
times = muonj.detect_monitor("muon_data_test.txt", mtime=20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 times = muonj.detect_monitor("muon_data_test.txt", mtime=20)
#
# File ~/src/Muon/MuonJupyter.py:170, in detect_monitor(fname, hgrange, mtime)
#     168 plt.ion()
#     169 times = np.array([])
# --> 170 with open(fname, "r") as datafile:
#     171     partial = ''
#     172     for line in datafile:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'muon_data_test.txt'
