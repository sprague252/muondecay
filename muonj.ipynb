# %%
import Muon.MuonJupyter as muonj
import numpy as np

# %%
c1 = muonj.controlpanel(['port', 'file'])

# %%
c1.file.value
# Out:
# 'muon.txt'

# %%
c1.append.value
# Out:
# False

# %%
muonj.deltaports()
# Out:
# Serial ports scanned ...
# Connect new device. Then press any key ...
# []

# %%
# ?np.setdiff1d
# Out:
# Signature: np.setdiff1d(ar1, ar2, assume_unique=False)
# Docstring:
# Find the set difference of two arrays.
#
# Return the unique values in `ar1` that are not in `ar2`.
#
# Parameters
# ----------
# ar1 : array_like
#     Input array.
# ar2 : array_like
#     Input comparison array.
# assume_unique : bool
#     If True, the input arrays are both assumed to be unique, which
#     can speed up the calculation.  Default is False.
#
# Returns
# -------
# setdiff1d : ndarray
#     1D array of values in `ar1` that are not in `ar2`. The result
#     is sorted when `assume_unique=False`, but otherwise only sorted
#     if the input is sorted.
#
# See Also
# --------
# numpy.lib.arraysetops : Module with a number of other functions for
#                         performing set operations on arrays.
#
# Examples
# --------
# >>> a = np.array([1, 2, 3, 2, 4, 1])
# >>> b = np.array([3, 4, 5, 6])
# >>> np.setdiff1d(a, b)
# array([1, 2])
# ...

# %%
from subprocess import Popen, STDOUT

# %%
fh = open('temp', 'w+')
proc = Popen(['sleep', '30;', 'ls', '-l'], stderr=STDOUT, stdout=fh)

# %% [raw]
# proc.pid

# %%
proc.args
# Out:
# ['sleep', '30;', 'ls', '-l']

# %%
proc=''

# %%
fh
# Out:
# <_io.TextIOWrapper name='temp' mode='w+' encoding='UTF-8'>

# %%
fh.closed
# Out:
# False

# %%
fh.close()

# %%
proc30 = Popen(['sleep', '30'])

# %%
proc30.pid
# Out:
# 17952

# %%
proc30=''

# %%
proc.pid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/70/bx93ndgs1qnb460scygh8x780000gp/T/ipykernel_17938/827051133.py in <module>
# ----> 1 proc.pid
#
# AttributeError: 'str' object has no attribute 'pid'

# %%
proc=''

# %%
proc30=''

# %%
pid = Popen(['sleep', '30']).pid
pid
# Out:
# 17954

# %%
pid = ''

# %%
str(10)
# Out:
# '10'

# %%
muonj.detect_monitor()
# Out:
# Monitor period 60 s ended.  Run again to continue monitoring.
# array([ 0.3 , 17.26,  9.06, ...,  1.34, 13.58, 14.92])

# %%
print(__name__)
# Out:
# __main__

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

# %%
import Muon.MuonJupyter as muonj
import numpy as np

# %%
# %matplotlib inline

# %%
times = muonj.detect_monitor("muon_data_test.txt", mtime=20)
# Out:
# Monitor period 20 s ended.  Run again to continue monitoring.
