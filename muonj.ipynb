# %%
import Muon.MuonJupyter as muonj
import numpy as np

# %%
c1 = muonj.controlpanel(['port', 'file'])

# %%
outfile = c1.file.value
port = c1.port.value

# %%
muonj.detect_spawn(port, outfile=outfile, sampletime=300)
# Out:
# <Popen: returncode: None args: ['python', '-m', 'Muon.detect', '-n', '0', '-...>

# %%
muonj.detect_monitor(fname=outfile, mtime=30)
# Out:
# Monitor period 30 s ended.  Run again to continue monitoring.
# array([ 0.04,  0.06,  0.06,  0.04,  0.06,  0.04,  0.04,  1.34,  0.06,
#         0.06,  0.06,  0.06,  0.04,  0.06,  0.06,  0.06,  0.06,  0.32,
#         0.06,  0.06,  0.06,  4.88,  0.06,  0.04,  0.06,  0.06,  0.06,
#         0.04,  0.06,  4.98,  0.04,  7.56,  0.04,  0.06,  0.04,  0.04,
#         0.06,  0.06,  0.04,  0.04,  0.04,  0.06,  0.06, 12.54,  0.06,
#         0.04,  0.04,  0.06,  0.04,  0.06,  0.06,  0.04,  0.04,  0.06,
#         0.06,  0.06,  0.06, 18.98,  0.04,  0.06,  6.84,  0.06,  0.8 ,
#         8.9 ,  0.04,  0.04,  0.06,  0.06,  0.04,  0.06,  0.06,  0.04,
#         0.06,  0.06,  0.06,  0.06,  0.06,  0.06,  0.04,  2.22,  0.04])

# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
muonj.detect_monitor(fname=outfile, mtime=30)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Monitor period 30 s ended.  Run again to continue monitoring.
# array([ 0.3 ,  2.06,  0.04,  0.04,  0.06,  0.06,  0.06,  0.04,  0.04,
#         0.04,  0.04,  0.04, 15.78,  0.06, 11.3 ,  0.06,  0.04,  0.06,
#         0.06,  0.06,  0.06,  0.06,  0.06,  0.06,  0.06,  0.04,  0.06,
#         0.06,  0.06,  0.04,  0.04,  0.06,  0.06,  0.06,  0.06,  0.06,
#         0.04,  0.06,  0.04,  0.06,  0.06,  0.04,  0.06,  0.06,  0.06,
#         0.06,  1.78,  0.06,  0.06,  0.06,  0.06,  0.06,  0.06,  0.04,
#         0.06, 14.  ,  0.06,  0.04,  0.04,  0.06,  0.06,  0.04,  0.04,
#         0.04,  0.06,  0.06,  0.24,  0.06, 19.18,  0.06,  0.06,  0.06,
#         0.06, 15.24,  0.06,  0.04,  0.06,  0.04,  0.06,  0.06,  0.04,
#         0.06,  0.04,  0.06,  0.04,  0.06,  0.04])
